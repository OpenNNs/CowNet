# %%
import numpy as np
from keras.models import Sequential
from keras.layers.core import Dense

# %%
# cargamos las 4 combinaciones de las compuertas XOR
training_data = np.array([[0,0],[0,1],[1,0],[1,1]])

# y estos son los resultados que se obtienen, en el mismo orden
target_data = np.array([[0],[1],[1],[0]])

# %%
model = Sequential()
model.add(Dense(16, activation='relu', input_shape=(2, )))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_29 (Dense)             (None, 16)                48
# _________________________________________________________________
# dense_30 (Dense)             (None, 8)                 136
# _________________________________________________________________
# dense_31 (Dense)             (None, 1)                 9
# ...
# Total params: 193
# Trainable params: 193
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
model.fit(training_data, target_data, validation_split=0.33,  
          epochs=1000, batch_size=10, verbose=1)
# Out:
# Train on 2 samples, validate on 2 samples
# Epoch 1/1000
# 2/2 [==============================] - 0s 102ms/step - loss: 0.7144 - accuracy: 0.5000 - val_loss: 0.6685 - val_accuracy: 0.5000
# Epoch 2/1000
# 2/2 [==============================] - 0s 1ms/step - loss: 0.7133 - accuracy: 0.0000e+00 - val_loss: 0.6697 - val_accuracy: 0.5000
# Epoch 3/1000
# 2/2 [==============================] - 0s 1ms/step - loss: 0.7116 - accuracy: 0.0000e+00 - val_loss: 0.6709 - val_accuracy: 0.5000
# Epoch 4/1000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.7099 - accuracy: 0.0000e+00 - val_loss: 0.6721 - val_accuracy: 0.5000
# Epoch 5/1000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.7082 - accuracy: 0.0000e+00 - val_loss: 0.6733 - val_accuracy: 0.5000
# Epoch 6/1000
# 2/2 [==============================] - 0s 1ms/step - loss: 0.7065 - accuracy: 0.0000e+00 - val_loss: 0.6746 - val_accuracy: 0.5000
# Epoch 7/1000
# ...

# %%
model.history.history.keys() # validation_split=0.33 for val_accuracy and val_loss
# Out:
# dict_keys(['val_loss', 'val_accuracy', 'loss', 'accuracy'])

# %%
import matplotlib.pyplot as plt
accuracy = model.history.history['accuracy']
val_accuracy = model.history.history['val_accuracy']
loss = model.history.history['loss']
val_loss = model.history.history['val_loss']
epochs = range(len(accuracy))
plt.plot(epochs, accuracy, 'r', label='Training accuracy')
plt.plot(epochs, val_accuracy, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend()
plt.figure()
plt.plot(epochs, loss, 'r', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend()
plt.show()

# %%
# summarize history for accuracy
plt.plot(model.history.history['accuracy'])
plt.plot(model.history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(model.history.history['loss'])
plt.plot(model.history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# evaluamos el modelo
scores = model.evaluate(training_data, target_data)
print("\n%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# 4/4 [==============================] - 0s 496us/step
#
# accuracy: 50.00%

# %%
print (model.predict(training_data).round())
# Out:
# [[0.]
#  [1.]
#  [0.]
#  [1.]]

# %%
#model.history.history

# %%
#model.history.history['accuracy']

# %%
from bokeh.plotting import figure, show
from bokeh.io import push_notebook, show, output_notebook
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %%
historic_pct=model.history.history['accuracy']
x = range(len(historic_pct))
y = historic_pct

historic_l=model.history.history['loss']
xl = range(len(historic_l))
yl = historic_l

p = figure(
    title="Porcetaje de aprendizaje en cada iteración",
    x_axis_label="Iter", y_axis_label="%", width=900)

p.line(x, y,  line_width=1)
p.line(xl, yl,  line_width=1)
#p.line(x, y, legend=None, line_width=1)
show(p)
# Out:
#   <div class="bk-root" id="b5742c14-3ab1-4971-bd5d-31499ead0b95" data-root-id="1002"></div>

# %%
import matplotlib.pyplot as plt
accuracy = model.history.history['accuracy']
#val_accuracy = model.history['val_accuracy']
loss = model.history.history['loss']
#val_loss = model.history.history['val_loss']
epochs = range(len(accuracy))
plt.plot(epochs, accuracy, 'r', label='Training accuracy')
#plt.plot(epochs, val_accuracy, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.legend()
plt.figure()
plt.plot(epochs, loss, 'r', label='Training loss')
#plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()
plt.show()

# %%
model.history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy'])
